# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\pranav\appdata\roaming\python\python311\site-packages (4.8.1.78)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\pranav\appdata\roaming\python\python311\site-packages (from opencv-python) (1.26.4)
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2

# %%
# read the image
image=cv2.imread("./download.jpg")

# %%
# check if the image is loaded correctly
if image is None:
    print("Error loading the image.")
else :
    print("Image loaded successfully")
# Out:
# Image loaded successfully

# %%
from matplotlib import pyplot as plt

# Convert image from BGR to RGB (OpenCV loads in BGR format)
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(rgb_image)
plt.axis('off')  # Hide axis
plt.title("Image Window")
plt.show()

# %%
image_new=image+30  
cv2.imwrite("./output.jpg",image_new)
# Out:
# True
